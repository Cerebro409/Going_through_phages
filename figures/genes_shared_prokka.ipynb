# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
prokka = pd.read_csv('PROKKA_CONNECTED_COMPONENTS.csv')
print(prokka)
# Out:
#       cluster            gene      Unnamed: 2      Unnamed: 3      Unnamed: 4  \
# 0           2  NNNJPOIF_00025  AAMILBOI_00046             NaN             NaN
# 1           8  PHBHOCAB_00002  IFAAAHMD_00008  BLGPNOEN_00002  AEAFPCAL_00003
# 2           6  BDFALBBM_00002  PNMLNJBE_00002  OCFEKFOI_00002  MGICCDHI_00002
# 3           9  MFDAJPNO_00010  AOKLCGBP_00007  EJFJIICA_00038  DPNMAKPO_00005
# 4           3  OFJEEBPC_00006  LBIPJCMD_00011  EJFNCMDJ_00004             NaN
# ...       ...             ...             ...             ...             ...
# 1488        1  CMLBKDKH_00064             NaN             NaN             NaN
# 1489        1  DGPDLLBB_00083             NaN             NaN             NaN
# 1490        1  CMLBKDKH_00070             NaN             NaN             NaN
# 1491        1  CMLBKDKH_00041             NaN             NaN             NaN
# 1492        1  EHOOANAO_00028             NaN             NaN             NaN
#
# ...

# %%
print (prokka['cluster'])
# Out:
# 0       2
# 1       8
# 2       6
# 3       9
# 4       3
#        ..
# 1488    1
# 1489    1
# 1490    1
# 1491    1
# 1492    1
# Name: cluster, Length: 1493, dtype: int64

# %%
prokka['cluster'].plot.hist(bins=20)
plt.title('Shared genes in 191 unique phage sequences')
plt.xlabel('Number of Phage from 0 to 191')
plt.ylabel('Number of Genes in cluster')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# 1494 gene clusters total - prokka
# 800 different genes only appeared in 1 genome
