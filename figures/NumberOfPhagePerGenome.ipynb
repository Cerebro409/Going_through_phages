# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('/home/tsweet/Going_through_Phages/data/prophage.csv')
print (df)
# Out:
#                                                  Genome  Count
# 0     GCA+AF8-000009005.1+AF8-ASM900v1+AF8-genomic.g...     22
# 1     GCA+AF8-000009585.1+AF8-ASM958v1+AF8-genomic.g...     20
# 2     GCA+AF8-000009645.1+AF8-ASM964v1+AF8-genomic.g...     18
# 3     GCA+AF8-000009665.1+AF8-ASM966v1+AF8-genomic.g...     19
# 4     GCA+AF8-000010445.1+AF8-ASM1044v1+AF8-genomic....     19
# ...                                                 ...    ...
# 9995                        GCA_001019115.2_ASM101911v2      0
# 9996                      GCA000546645.1StapaureM1035V1      0
# 9997                          GCA002260105.1ASM226010v1      0
# 9998                          GCA003239265.1ASM323926v1      0
# 9999                             GCA900125785.117175181      0
#
# [10000 rows x 2 columns]

# %%
df['Count'].plot.hist(bins=30)
plt.title('Distribution of Prophage (Phage) in S.aureus Genome')
plt.xlabel('Number of Phage lowest=0, highest=25')
plt.ylabel('Number of Genomes 0 - 10K')
plt.grid(axis='y', alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
PhageCount = df['Count']
SomeData=pd.Series(PhageCount, index=np.arange(9995))
print(PhageCount)
# Out:
# 0       22
# 1       20
# 2       18
# 3       19
# 4       19
#         ..
# 9995     0
# 9996     0
# 9997     0
# 9998     0
# 9999     0
# Name: Count, Length: 10000, dtype: int64

# %%
SomeData.hist(grid=True,bins=50,rwidth=0.9,color='#607c8e')
plt.title('Distribution of Prophage (Phage) in S.aureus Genome')
plt.xlabel('Number of Phage lowest=0, highest=25')
plt.ylabel('Number of Genomes 0 - 10K')
plt.grid(axis='y', alpha=0.75)

# %%
# Caption: Detected a total of 196,727 prophage sequences across the 10,000 Genomes. 
#          1125 S. aureus sequences had 25 phage regions present. 
#          The x-axis reflects the exact totals each genome contained per genome (y-axis)
