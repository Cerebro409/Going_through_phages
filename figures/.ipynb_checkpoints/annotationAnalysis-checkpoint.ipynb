# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df_prokka_accession = pd.read_csv('/home/tsweet/Going_through_Phages/data/Gene_Function_Analysis_Data - Prokka_matrix_gene_function.csv')
print(df_prokka_accession)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-2c9ae969129d> in <module>
# ----> 1 df_prokka_accession = pd.read_csv('/home/tsweet/Going_through_Phages/data/Gene_Function_Analysis_Data - Prokka_matrix_gene_function.csv')
#       2 print(df_prokka_accession)
#
# ...

# %%
df_prokka_accession["prophage_ID"].plot.bar
plt.title('Number of Genomes per Unique Prophage')
plt.xlabel('Number of Genome')
plt.ylabel('Number of Phage')
plt.grid(axis='y', alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="640">
