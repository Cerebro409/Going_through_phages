# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
vgas = pd.read_csv('VGAS_CONNECTED_COMPONENTS.csv')
print(vgas)
# Out:
#       cluster                                    gene  \
# 0           1        Potential_gene_1:232..441_210_bp
# 1           6          Potential_gene_1:7..708_702_bp
# 2           3   Potential_gene_40:37845..38348_504_bp
# 3           2   Potential_gene_14:11200..11490_291_bp
# 4           2   Potential_gene_20:18389..18916_528_bp
# ...       ...                                     ...
# 1523        1  Potential_gene_62:61403..62635_1233_bp
# 1524        1   Potential_gene_78:89535..90401_867_bp
# 1525        1   Potential_gene_29:29778..30182_405_bp
# 1526        1        Potential_gene_1:222..440_219_bp
# 1527        1        Potential_gene_1:200..814_615_bp
#
#                                  Unnamed: 2  \
# 0                                       NaN
# 1        Potential_gene_8:7954..8655_702_bp
# 2     Potential_gene_30:28316..28819_504_bp
# 3     Potential_gene_33:31448..31738_291_bp
# 4       Potential_gene_10:8860..9387_528_bp
# ...                                     ...
# 1523                                    NaN
# 1524                                    NaN
# 1525                                    NaN
# 1526                                    NaN
# 1527                                    NaN
#
#                               Unnamed: 3                          Unnamed: 4  \
# 0                                    NaN                                 NaN
# 1      Potential_gene_1:750..1451_702_bp  Potential_gene_4:4632..5333_702_bp
# 2     Potential_gene_2:1388..1891_504_bp                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# ...                                  ...                                 ...
# 1523                                 NaN                                 NaN
# 1524                                 NaN                                 NaN
# 1525                                 NaN                                 NaN
# 1526                                 NaN                                 NaN
# 1527                                 NaN                                 NaN
#
#                                  Unnamed: 5  \
# 0                                       NaN
# 1     Potential_gene_37:38585..39286_702_bp
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1523                                    NaN
# 1524                                    NaN
# 1525                                    NaN
# 1526                                    NaN
# 1527                                    NaN
#
#                               Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                                    NaN        NaN        NaN        NaN
# 1     Potential_gene_2:1306..2007_702_bp        NaN        NaN        NaN
# 2                                    NaN        NaN        NaN        NaN
# 3                                    NaN        NaN        NaN        NaN
# 4                                    NaN        NaN        NaN        NaN
# ...                                  ...        ...        ...        ...
# 1523                                 NaN        NaN        NaN        NaN
# 1524                                 NaN        NaN        NaN        NaN
# 1525                                 NaN        NaN        NaN        NaN
# 1526                                 NaN        NaN        NaN        NaN
# 1527                                 NaN        NaN        NaN        NaN
#
#      Unnamed: 10
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1523         NaN
# 1524         NaN
# 1525         NaN
# 1526         NaN
# 1527         NaN
#
# [1528 rows x 11 columns]

# %%
print (vgas['cluster'])
# Out:
# 0       1
# 1       6
# 2       3
# 3       2
# 4       2
#        ..
# 1523    1
# 1524    1
# 1525    1
# 1526    1
# 1527    1
# Name: cluster, Length: 1528, dtype: int64

# %%
vgas['cluster'].plot.hist(bins=10)
plt.title('Shared genes in 191 unique phage sequences')
plt.xlabel('Number of Phage from 0 to 191')
plt.ylabel('Number of Genes in cluster')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# 1529 gene clusters total - vgas
# 800 different genes only appeared in 1 genome
