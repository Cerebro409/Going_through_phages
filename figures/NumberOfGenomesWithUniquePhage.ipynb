# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb

# %%
df = pd.read_csv('/home/tsweet/Going_through_Phages/data/ConnectedComponentsFinalFixed.csv')
print (df)
# Out:
#      Cluster                                            Genomes  \
# 0          1  GCA_000525445.1_Stap_aure_DAR5883_V1_genomic.g...
# 1          1  GCA_000546485.1_Stap_aure_M1022_V1_genomic.gbff_6
# 2          1  GCA_000547705.1_Stap_aure_M0758_V1_genomic.gbf...
# 3          1  GCA_000555845.1_Stap_aure_M0421_V1_genomic.gbff_7
# 4          1  GCA_000556025.1_Stap_aure_M0437_V1_genomic.gbf...
# ..       ...                                                ...
# 186     9739           GCA_000009005.1_ASM900v1_genomic.gbff_20
# 187     9739            GCA_000009005.1_ASM900v1_genomic.gbff_4
# 188     9739            GCA_000009005.1_ASM900v1_genomic.gbff_8
# 189     9739            GCA_000009005.1_ASM900v1_genomic.gbff_9
# 190     9995           GCA_000009005.1_ASM900v1_genomic.gbff_14
#
#                                    Unnamed: 2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# ...

# %%
df['Cluster'].plot.hist(bins=20)
plt.title('Distribution of unique prophage in the 10K genomes')
plt.xlabel('Number of genomes from 0 to 10,000')
plt.ylabel('Number of Phage from 0 to 191')
plt.grid(axis='y', alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
# Caption:There were a few phage found that were found in nearly every genome sequence.
#         191 prophages with an average of 1024 (Standard deviation = 2581.33).
#         The highest number of genomes a single phage was detected is 9995, and the lowest was 1.
