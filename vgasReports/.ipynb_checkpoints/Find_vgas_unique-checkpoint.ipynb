# %%
# Install Dependencies
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.6 MB 6.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.0 MB 1.0 MB/s eta 0:00:01
# ...

# %%
# Import packages
import pandas as pd
import numpy as np

# %%
vgas_unique_edges = pd.read_csv('vgas_unique.txt', header = None)
print (vgas_unique_edges)
# Out:
#                                                     0  \
# 0      GCA_000009005.1_ASM900v1_genomic.gbff_pp16.ffn
# 1       GCA_000009005.1_ASM900v1_genomic.gbff_pp6.ffn
# 2       GCA_000009005.1_ASM900v1_genomic.gbff_pp7.ffn
# 3       GCA_000009585.1_ASM958v1_genomic.gbff_pp5.ffn
# 4       GCA_000009645.1_ASM964v1_genomic.gbff_pp2.ffn
# 5      GCA_000011505.1_ASM1150v1_genomic.gbff_pp6.ffn
# 6      GCA_000013425.1_ASM1342v1_genomic.gbff_pp6.ffn
# 7     GCA_000160355.1_ASM16035v1_genomic.gbff_pp3.ffn
# 8     GCA_000160415.1_ASM16041v1_genomic.gbff_pp7.ffn
# 9     GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ffn
# 10    GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ffn
# 11    GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ffn
# 12    GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ffn
# 13    GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ffn
# 14    GCA_000242555.2_ASM24255v2_genomic.gbff_pp2.ffn
# 15  GCA_000363845.1_Stap_aure_B40950_V1_genomic.gb...
# ...

# %%
vgas_edges = pd.read_csv('VGAS_EDGES2', header = None)
print (vgas_edges)
# Out:
#                                                     0  \
# 0       GCA_000009005.1_ASM900v1_genomic.gbff_pp1.ffn
# 1       GCA_000009005.1_ASM900v1_genomic.gbff_pp1.ffn
# 2       GCA_000009005.1_ASM900v1_genomic.gbff_pp1.ffn
# 3       GCA_000009005.1_ASM900v1_genomic.gbff_pp1.ffn
# 4      GCA_000009005.1_ASM900v1_genomic.gbff_pp10.ffn
# ...                                               ...
# 1328  GCA_900482705.1_7915_6_43_genomic.gbff_pp16.ffn
# 1329  GCA_900482705.1_7915_6_43_genomic.gbff_pp16.ffn
# 1330  GCA_900482705.1_7915_6_43_genomic.gbff_pp16.ffn
# 1331  GCA_900482705.1_7915_6_43_genomic.gbff_pp16.ffn
# 1332  GCA_900482705.1_7915_6_43_genomic.gbff_pp16.ffn
#
#                                                       1   2
# 0       GCA_000215405.2_ASM21540v2_genomic.gbff_pp1.ffn   9
# 1        GCA_000011505.1_ASM1150v1_genomic.gbff_pp2.ffn  13
# 2     GCA_000547345.1_Stap_aure_M1562_V1_genomic.gbf...   7
# 3         GCA_000009645.1_ASM964v1_genomic.gbff_pp1.ffn  11
# ...

# %%
df_all_cols = pd.concat([vgas_unique_edges, vgas_edges], axis = 1)
df_all_cols
# Out:
#                                                    0  \
# 0     GCA_000009005.1_ASM900v1_genomic.gbff_pp16.ffn
# 1      GCA_000009005.1_ASM900v1_genomic.gbff_pp6.ffn
# 2      GCA_000009005.1_ASM900v1_genomic.gbff_pp7.ffn
# 3      GCA_000009585.1_ASM958v1_genomic.gbff_pp5.ffn
# 4      GCA_000009645.1_ASM964v1_genomic.gbff_pp2.ffn
# ...                                              ...
# 1328                                             NaN
# 1329                                             NaN
# 1330                                             NaN
# 1331                                             NaN
# 1332                                             NaN
#
#                                                       1  \
# 0      GCA_000009005.1_ASM900v1_genomic.gbff_pp16.ff...
# 1     GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ff...
# 2     GCA_000009005.1_ASM900v1_genomic.gbff_pp7.ffn ...
# 3     GCA_000163575.1_ASM16357v1_genomic.gbff_pp4.ff...
# ...

# %%
df_all_cols.to_csv('vgas_unique_edges_count.csv', encoding='utf-8', index=False)
